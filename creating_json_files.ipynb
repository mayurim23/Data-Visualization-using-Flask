# %%
import json
import numpy as np

###########################################2002 ######################################################################
with open('connecticut_counties.geojson', 'r') as json_file:
    counties_2002 = json.load(json_file)
for v in counties_2002["features"]:
    if(v["properties"]["name"]=='Litchfield County, CT'):
        v["properties"]["Yale_Hospital"] = 1543
        v["properties"]["Bristol_Hospital"] = 935
        v["properties"]["Gaylord_Hospital"] = 756
        v["properties"]["Total_Cases_2002"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='New London County, CT'):
        v["properties"]["Yale_Hospital"] = 200
        v["properties"]["Bristol_Hospital"] = 100
        v["properties"]["Gaylord_Hospital"] = 152
        v["properties"]["Total_Cases_2002"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Middlesex County, CT'):
        v["properties"]["Yale_Hospital"] = 858
        v["properties"]["Bristol_Hospital"] = 550
        v["properties"]["Gaylord_Hospital"] = 450
        v["properties"]["Total_Cases_2002"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Tolland County, CT'):
        v["properties"]["Yale_Hospital"] = 1562
        v["properties"]["Bristol_Hospital"] = 987
        v["properties"]["Gaylord_Hospital"] = 592
        v["properties"]["Total_Cases_2002"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Windham County, CT'):
        v["properties"]["Yale_Hospital"] = 1750
        v["properties"]["Bristol_Hospital"] = 1250
        v["properties"]["Gaylord_Hospital"] = 430
        v["properties"]["Total_Cases_2002"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"] 
    if(v["properties"]["name"]=='Fairfield County, CT'):
        v["properties"]["Yale_Hospital"] = 2960
        v["properties"]["Bristol_Hospital"] = 552
        v["properties"]["Gaylord_Hospital"] = 500
        v["properties"]["Total_Cases_2002"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='New Haven County, CT'):
        v["properties"]["Yale_Hospital"] = 876
        v["properties"]["Bristol_Hospital"] = 721
        v["properties"]["Gaylord_Hospital"] = 516
        v["properties"]["Total_Cases_2002"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Hartford County, CT'):
        v["properties"]["Yale_Hospital"] = 346
        v["properties"]["Bristol_Hospital"] =276
        v["properties"]["Gaylord_Hospital"] = 82
        v["properties"]["Total_Cases_2002"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]

with open("Hospitals_2002.geojson", 'w') as json_file:
    json.dump(counties_2002, json_file)
    
##########################################2003############################################    
with open('connecticut_counties.geojson', 'r') as json_file:
    counties_2003 = json.load(json_file)
for v in counties_2003["features"]:
    if(v["properties"]["name"]=='Litchfield County, CT'):
        v["properties"]["Yale_Hospital"] = 1432
        v["properties"]["Bristol_Hospital"] = 1271
        v["properties"]["Gaylord_Hospital"] = 867
        v["properties"]["Total_Cases_2003"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='New London County, CT'):
        v["properties"]["Yale_Hospital"] = 399
        v["properties"]["Bristol_Hospital"] = 301
        v["properties"]["Gaylord_Hospital"] = 249
        v["properties"]["Total_Cases_2003"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Middlesex County, CT'):
        v["properties"]["Yale_Hospital"] = 1465
        v["properties"]["Bristol_Hospital"] = 987
        v["properties"]["Gaylord_Hospital"] = 801
        v["properties"]["Total_Cases_2003"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Tolland County, CT'):
        v["properties"]["Yale_Hospital"] = 1456
        v["properties"]["Bristol_Hospital"] = 1315
        v["properties"]["Gaylord_Hospital"] = 1002
        v["properties"]["Total_Cases_2003"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Windham County, CT'):
        v["properties"]["Yale_Hospital"] = 986
        v["properties"]["Bristol_Hospital"] = 876
        v["properties"]["Gaylord_Hospital"] = 407
        v["properties"]["Total_Cases_2003"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"] 
    if(v["properties"]["name"]=='Fairfield County, CT'):
        v["properties"]["Yale_Hospital"] = 2000
        v["properties"]["Bristol_Hospital"] = 1500
        v["properties"]["Gaylord_Hospital"] = 500
        v["properties"]["Total_Cases_2003"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='New Haven County, CT'):
        v["properties"]["Yale_Hospital"] = 1441
        v["properties"]["Bristol_Hospital"] = 550
        v["properties"]["Gaylord_Hospital"] = 260
        v["properties"]["Total_Cases_2003"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Hartford County, CT'):
        v["properties"]["Yale_Hospital"] = 72
        v["properties"]["Bristol_Hospital"] =27
        v["properties"]["Gaylord_Hospital"] = 15
        v["properties"]["Total_Cases_2003"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
with open("Hospitals_2003.geojson", 'w') as json_file:
    json.dump(counties_2003, json_file)


########################################2004#######################################
with open('connecticut_counties.geojson', 'r') as json_file:
    counties_2004 = json.load(json_file)
for v in counties_2004["features"]:
    if(v["properties"]["name"]=='Litchfield County, CT'):
        v["properties"]["Yale_Hospital"] = 1339
        v["properties"]["Bristol_Hospital"] = 1066
        v["properties"]["Gaylord_Hospital"] = 1023
        v["properties"]["Total_Cases_2004"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='New London County, CT'):
        v["properties"]["Yale_Hospital"] = 295
        v["properties"]["Bristol_Hospital"] = 205
        v["properties"]["Gaylord_Hospital"] = 110
        v["properties"]["Total_Cases_2004"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Middlesex County, CT'):
        v["properties"]["Yale_Hospital"] = 1523
        v["properties"]["Bristol_Hospital"] = 1261
        v["properties"]["Gaylord_Hospital"] = 472
        v["properties"]["Total_Cases_2004"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Tolland County, CT'):
        v["properties"]["Yale_Hospital"] = 1550
        v["properties"]["Bristol_Hospital"] = 1450
        v["properties"]["Gaylord_Hospital"] = 618
        v["properties"]["Total_Cases_2004"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Windham County, CT'):
        v["properties"]["Yale_Hospital"] = 1200
        v["properties"]["Bristol_Hospital"] = 908
        v["properties"]["Gaylord_Hospital"] = 701
        v["properties"]["Total_Cases_2004"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"] 
    if(v["properties"]["name"]=='Fairfield County, CT'):
        v["properties"]["Yale_Hospital"] = 1548
        v["properties"]["Bristol_Hospital"] = 1432
        v["properties"]["Gaylord_Hospital"] = 856
        v["properties"]["Total_Cases_2004"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='New Haven County, CT'):
        v["properties"]["Yale_Hospital"] = 1569
        v["properties"]["Bristol_Hospital"] =610
        v["properties"]["Gaylord_Hospital"] = 596
        v["properties"]["Total_Cases_2004"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    if(v["properties"]["name"]=='Hartford County, CT'):
        v["properties"]["Yale_Hospital"] = 267
        v["properties"]["Bristol_Hospital"] =226
        v["properties"]["Gaylord_Hospital"] = 145
        v["properties"]["Total_Cases_2004"]=v["properties"]["Yale_Hospital"]+v["properties"]["Bristol_Hospital"]+v["properties"]["Gaylord_Hospital"]
    
with open("Hospitals_2004.geojson", 'w') as json_file:
    json.dump(counties_2004, json_file)

# %%
import json
with open('Hospitals_2004.geojson', 'r') as json_file:
    counties_2002 = json.load(json_file)
for v in counties_2002["features"]:
     print((v["properties"]["name"]))
# Out:
# New London County, CT
# Hartford County, CT
# Middlesex County, CT
# Litchfield County, CT
# Tolland County, CT
# Windham County, CT
# Fairfield County, CT
# New Haven County, CT
